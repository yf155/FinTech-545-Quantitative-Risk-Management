# %% [markdown]
# Week 2 Project

# %%
from scipy.stats import kurtosis
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import statsmodels.api as sm

# %% [markdown]
# Problem 3

# %%
#Simulation of AR(1)
plt.subplot(1, 1, 1)
ar1 = np.array([1, -0.5])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
AR_1 = AR_object1.generate_sample(nsample=2000)
plt.plot(AR_1)

# %%
#ACF of AR(1)
plot_acf(AR_1, alpha=1, lags=20);

# %%
#PACF of AR(1)
plot_pacf(AR_1, lags=20)

# %%
#Simulation of AR(2)
plt.subplot(1, 1, 1)
ar2 = np.array([1, -0.5, -0.25])
ma2 = np.array([1])
AR_object2 = ArmaProcess(ar2, ma2)
AR_2 = AR_object2.generate_sample(nsample=2000)
plt.plot(AR_2)

# %%
#ACF of AR(2)
plot_acf(AR_2, alpha=1, lags=20);

# %%
#PACF of AR(2)
plot_pacf(AR_2, lags=20)

# %%
#Simulation of AR(3)
plt.subplot(1, 1, 1)
ar3 = np.array([1, -0.5, -0.25, -0.125])
ma3 = np.array([1])
AR_object3 = ArmaProcess(ar3, ma3)
AR_3 = AR_object3.generate_sample(nsample=2000)
plt.plot(AR_3)

# %%
#ACF of AR(3)
plot_acf(AR_3, alpha=1, lags=20);

# %%
#PACF of AR(3)
plot_pacf(AR_3, lags=20)

# %%
#Simulation of MA(1)
plt.subplot(1, 1, 1)
ar1 = np.array([1])
ma1 = np.array([1, -0.5])
MA_object1 = ArmaProcess(ar1, ma1)
MA_1 = MA_object1.generate_sample(nsample=2000)
plt.plot(MA_1)

# %%
#ACF of MA(1)
plot_acf(MA_1, alpha=1, lags=20);

# %%
#PACF of MA(1)
plot_pacf(MA_1, lags=20)

# %%
#Simulation of MA(2)
plt.subplot(1, 1, 1)
ar2 = np.array([1])
ma2 = np.array([1, -0.5,0.4])
MA_object2 = ArmaProcess(ar2, ma2)
MA_2 = MA_object2.generate_sample(nsample=2000)
plt.plot(MA_2)

# %%
#ACF of MA(2)
plot_acf(MA_2, alpha=1, lags=20);

# %%
#PACF of MA(2)
plot_pacf(MA_2, lags=20)

# %%
#Simulation of MA(3)
plt.subplot(1, 1, 1)
ar3 = np.array([1])
ma3 = np.array([1, -0.5, 0.4, -4/7])
MA_object3 = ArmaProcess(ar3, ma3)
MA_3 = MA_object3.generate_sample(nsample=2000)
plt.plot(MA_3)

# %%
#ACF of MA(3)
plot_acf(MA_3, alpha=1, lags=20);

# %%
#PACF of MA(3)
plot_pacf(MA_3, lags=20)

# %%
model = sm.tsa.arima.ARIMA(AR_1, order=(1,1,1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2856.796
# Date:                Sat, 28 Jan 2023   AIC                           5719.592
# Time:                        01:58:07   BIC                           5736.393
# Sample:                             0   HQIC                          5725.761
#                                - 2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4829      0.020     24.054      0.000       0.444       0.522
# ma.L1         -1.0000      0.073    -13.611      0.000      -1.144      -0.856
# sigma2         1.0172      0.081     12.515      0.000       0.858       1.177
# ...

# %%
model = sm.tsa.arima.ARIMA(AR_2, order=(1,1,1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2926.671
# Date:                Sat, 28 Jan 2023   AIC                           5859.341
# Time:                        01:58:07   BIC                           5876.143
# Sample:                             0   HQIC                          5865.511
#                                - 2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3368      0.038      8.764      0.000       0.261       0.412
# ma.L1         -0.7463      0.027    -27.667      0.000      -0.799      -0.693
# sigma2         1.0943      0.033     32.696      0.000       1.029       1.160
# ...

# %%
model = sm.tsa.arima.ARIMA(AR_3, order=(1,1,1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2875.354
# Date:                Sat, 28 Jan 2023   AIC                           5756.707
# Time:                        01:58:07   BIC                           5773.508
# Sample:                             0   HQIC                          5762.876
#                                - 2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1139      0.046     -2.456      0.014      -0.205      -0.023
# ma.L1         -0.3816      0.043     -8.949      0.000      -0.465      -0.298
# sigma2         1.0395      0.031     33.088      0.000       0.978       1.101
# ...

# %%
model = sm.tsa.arima.ARIMA(MA_1, order=(1,1,1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2880.534
# Date:                Sat, 28 Jan 2023   AIC                           5767.069
# Time:                        01:58:08   BIC                           5783.870
# Sample:                             0   HQIC                          5773.238
#                                - 2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4128      0.021    -19.873      0.000      -0.454      -0.372
# ma.L1         -0.9999      0.028    -35.345      0.000      -1.055      -0.944
# sigma2         1.0407      0.045     23.210      0.000       0.953       1.129
# ...

# %%
model = sm.tsa.arima.ARIMA(MA_2, order=(1,1,1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2872.081
# Date:                Sat, 28 Jan 2023   AIC                           5750.161
# Time:                        01:58:08   BIC                           5766.963
# Sample:                             0   HQIC                          5756.331
#                                - 2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4994      0.020    -24.813      0.000      -0.539      -0.460
# ma.L1         -0.9666      0.006   -161.973      0.000      -0.978      -0.955
# sigma2         1.0343      0.034     30.470      0.000       0.968       1.101
# ...

# %%
model = sm.tsa.arima.ARIMA(MA_3, order=(1,1,1))
result = model.fit()
print(result.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                 2000
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -3031.930
# Date:                Sat, 28 Jan 2023   AIC                           6069.860
# Time:                        01:58:09   BIC                           6086.661
# Sample:                             0   HQIC                          6076.029
#                                - 2000
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.5474      0.019    -29.544      0.000      -0.584      -0.511
# ma.L1         -0.9998      0.040    -24.877      0.000      -1.079      -0.921
# sigma2         1.2109      0.062     19.635      0.000       1.090       1.332
# ...
